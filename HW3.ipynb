# %% [markdown]
# <a href="https://colab.research.google.com/github/yossefPartouche/Deep_Learning/blob/main/HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 3
#
# ## Instructions:
#
# - All previous instructions hold.
# - In addition, if you are using GPU, you must check that your code also runs on a CPU.
# - **Make sure you use the best practices you learned in class**.

# %% [markdown]
# ## Intro:
#
# So far we had to manually implement both the forward and backward passes of our neural network. Manually implementing the backward pass is not a big deal for a small two-layer network, but can quickly get very messy for large complex networks.
#
# Thankfully, We learned in the reciation that we can use **automatic differentiation** to automate the computation of backward passes in neural networks. The autograd package in PyTorch provides exactly this functionality. When using autograd, the forward pass of your network will define a computational graph. Nodes in the graph will be Tensors,
# and edges will be functions that produce output Tensors from input Tensors. Backpropagating through this graph then allows you to easily compute gradients.
#
# If we want to compute gradients with respect to some Tensor, then we set `requires_grad=True` when constructing that Tensor. Any PyTorch operations on that Tensor will cause a computational graph to be constructed, allowing us to later perform backpropagation through the graph. If `x` is a Tensor with `requires_grad=True`, then after backpropagation `x.grad` will be another Tensor holding the gradient of `x`.
#
# Sometimes you may wish to prevent PyTorch from building computational graphs when performing certain operations on Tensors with `requires_grad=True`; for example, we usually don't want to backpropagate through the weight update steps when evaluating a neural network. In such scenarios we can use the `torch.no_grad()` context manager to prevent the construction of a computational graph.
#
# ## In this exercise, you will accomplish the following:
# 1. Train a convolutional network using PyTorch.
# 2. Evaluate your model using a confusion matrix.
# 3. Solve the localization task using regression.

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from google.colab import drive
from torchsummary import summary
import sys
import os

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %% [markdown]
# # Part A (40 points)
# # Convolutional Neural Network - Classifiying CIFAR-10

# %% [markdown]
# ### Data Preprocessing

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])


train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=(0.4914, 0.4822, 0.4465),
        std=(0.2023, 0.1994, 0.2010)
    )
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(
        mean=(0.4914, 0.4822, 0.4465),
        std=(0.2023, 0.1994, 0.2010)
    )
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=train_transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
# functions to show an image
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0))) # plt accepts images in the format (w,h,c)

# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)

print("Image shape: ", images[0].shape)
# show images
imshow(torchvision.utils.make_grid(images[:4]))
# print labels
print(' '.join('%10s' % classes[labels[j]] for j in range(4)))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.8768656].
# Image shape:  torch.Size([3, 32, 32])
#       frog       deer       ship      horse

# %% [markdown]
# ### Construct a CNN in PyTorch
#
# In the following class, initiate your different layers in the `__init__` method and define your architecture in the `forward` method. Make sure the `forward` method has a single return value.
#
# 1. Make good use of the documentation and experiment will different layers, activations and architectures, batch sizes, regularization, filter sizes, dimensions, number of layers and whatever you learned in class.
# 2. Use your intuition from the previous exercises and additional sources such as the stackoverflow, Medium, etc. - **do not try to perform a massive grid search.**
# 3. **Include only your chosen architecture**. During experimentation, you may add as many cells as you need. Make sure to delete them before submission.
# 4. It is **NOT** allowed to use famous models that have been already implemented by PyTorch (resnet, densenet, alexnet, etc).
# 5. Make sure your code runs reasonably fast (no more than 15 minutes on CPU).
# 6. Use the best architecture you find and train it for 1-10 epochs.
# 7. Visualize the loss and accuracy of your network during training. You can use matplotlib.
# 8. You should get above 60% accuracy on the test set.
# **(20 points)**

# %%
from torch.nn.modules.pooling import MaxPool1d
from torch.nn.modules.activation import ReLU


class ResidualBlock(nn.Module):
  def __init__(self, channels):
    super().__init__()
    self.conv = nn.Sequential(
        nn.Conv2d(channels, channels, 3, padding=1),
        nn.ReLU(),
        nn.Conv2d(channels, channels, 3, padding=1)
    )
  def forward(self, x):
    return torch.relu(self.conv(x) + x)

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        #############################################################################
        # TO DO:                                                                    #
        # Initiate the different layers you wish to use in your network.            #
        # This method has no return value.                                          #
        #############################################################################
        self.features = torch.nn.Sequential(
          nn.Conv2d(3, 6, 3),
          nn.BatchNorm2d(6),
          nn.ReLU(),

          ResidualBlock(6),
          nn.Conv2d(6, 6, 3),
          nn.BatchNorm2d(6),
          nn.ReLU(),

          nn.Conv2d(6, 16, 5),
          nn.BatchNorm2d(16),
          nn.ReLU(),

          ResidualBlock(16),
          nn.Conv2d(16, 16, kernel_size=3, stride=2, padding=2),
          nn.BatchNorm2d(16),
          nn.ReLU()
        )
        self.classifier = nn.Sequential(
          nn.Linear(16*13*13, 120),
          nn.ReLU(),
          nn.Linear(120, 84),
          nn.ReLU(),
          nn.Linear(84,10)
        )
        #############################################################################
        #                             END OF YOUR CODE                              #
        #############################################################################

    def forward(self, x):
        #############################################################################
        # TO DO:                                                                    #
        # Define the forward propagation. You need to pass an image through the     #
        # network and obtain class predictions.                                     #
        # This function returns the prediction of your model.                      #
        #############################################################################
        x = self.features(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x
        #############################################################################
        #                             END OF YOUR CODE                              #
        #############################################################################

device = torch.device("cpu")
#net = Net().to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))
print(f"Using device: {device}")
#############################################################################
# TO DO:                                                                    #
# Define the loss function and optimizer.                                   #
#############################################################################
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)


#############################################################################
#                             END OF YOUR CODE                              #
#############################################################################
# Out:
# Using device: cpu

# %%
images, labels = next(iter(trainloader))
print(images.shape)
summary(model=net, input_size = images.shape[1:])
# Out:
# torch.Size([64, 3, 32, 32])
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 30, 30]             168
#        BatchNorm2d-2            [-1, 6, 30, 30]              12
#               ReLU-3            [-1, 6, 30, 30]               0
#             Conv2d-4            [-1, 6, 30, 30]             330
#               ReLU-5            [-1, 6, 30, 30]               0
#             Conv2d-6            [-1, 6, 30, 30]             330
#      ResidualBlock-7            [-1, 6, 30, 30]               0
#             Conv2d-8            [-1, 6, 28, 28]             330
#        BatchNorm2d-9            [-1, 6, 28, 28]              12
#              ReLU-10            [-1, 6, 28, 28]               0
#            Conv2d-11           [-1, 16, 24, 24]           2,416
#       BatchNorm2d-12           [-1, 16, 24, 24]              32
#              ReLU-13           [-1, 16, 24, 24]               0
#            Conv2d-14           [-1, 16, 24, 24]           2,320
#              ReLU-15           [-1, 16, 24, 24]               0
#            Conv2d-16           [-1, 16, 24, 24]           2,320
#     ResidualBlock-17           [-1, 16, 24, 24]               0
#            Conv2d-18           [-1, 16, 13, 13]           2,320
#       BatchNorm2d-19           [-1, 16, 13, 13]              32
#              ReLU-20           [-1, 16, 13, 13]               0
#            Linear-21                  [-1, 120]         324,600
#              ReLU-22                  [-1, 120]               0
#            Linear-23                   [-1, 84]          10,164
#              ReLU-24                   [-1, 84]               0
#            Linear-25                   [-1, 10]             850
# ================================================================
# Total params: 346,236
# Trainable params: 346,236
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.95
# Params size (MB): 1.32
# Estimated Total Size (MB): 2.29
# ----------------------------------------------------------------

# %%
#############################################################################
# TO DO:                                                                    #
# Define the training loop as seen in class and as demonstrated in the       #
# documentation. Note, if you are using GPU, make sure your code runs on    #
# CPU also. Code that cannot run will not be tested.                        #
#############################################################################
def train_model(model, train_loader, num_epochs):
  device = next(model.parameters()).device

  train_losses = []
  train_accs = []

  for epoch in range(num_epochs):

    total_loss, total_correct, total = 0.0, 0, 0
    model.train()

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        total_loss += loss.item() * inputs.size(0)
        total_correct += (outputs.argmax(1) == labels).sum().item()
        total += inputs.size(0)

    train_loss = total_loss / total
    train_acc = total_correct / total

    #------- Store History-------

    train_losses.append(train_loss)
    train_accs.append(train_acc)


    print(f"Epoch {epoch:02d} | train_loss={train_loss:.4f} train_acc={train_acc:.3f} ")

  return train_losses, train_accs


# -----------------------------------------------------------------------   #
# ---------------------------train & plots-------------------------------   #
# -----------------------------------------------------------------------   #









#############################################################################
#                             END OF YOUR CODE                              #
#############################################################################

# %%
EPOCHS = 10  # You can adjust the number of epochs as needed
train_losses, train_accs = train_model(net, trainloader, EPOCHS)
# Out:
# Epoch 00 | train_loss=1.0382 train_acc=0.631
# Epoch 01 | train_loss=1.0104 train_acc=0.639
# Epoch 02 | train_loss=0.9857 train_acc=0.651
# Epoch 03 | train_loss=0.9677 train_acc=0.655
# Epoch 04 | train_loss=0.9489 train_acc=0.660
# Epoch 05 | train_loss=0.9317 train_acc=0.668
# Epoch 06 | train_loss=0.9178 train_acc=0.673
# Epoch 07 | train_loss=0.9011 train_acc=0.680
# Epoch 08 | train_loss=0.8924 train_acc=0.683
# Epoch 09 | train_loss=0.8756 train_acc=0.689

# %%
epochs = range(1, EPOCHS+1)

# --- Plot 1 ---
plt.figure()
plt.plot(epochs, train_losses, marker='o', label='train loss',color='c')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('Loss vs. Epoch')
plt.legend()
plt.grid(color = 'lightgray', linestyle = '--', linewidth = 0.5)
plt.tight_layout(); plt.show()

# --- Plot 2 ---
plt.figure()
plt.plot(epochs, train_accs, marker='o', label='train acc',color='c')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.title('Accuracy vs. Epoch')
plt.legend()
plt.grid(color = 'lightgray', linestyle = '--', linewidth = 0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Explainability
#
# $\text{ We present different methods to understand what's happening inside the Network}$

# %%
images, labels = next(iter(testloader))
img = images[0:1].to(device)

with torch.no_grad():
  features = net.features(img)

  fmaps = features.squeeze(0).cpu()
  num_maps = fmaps.shape[0]
  cols = 8
  rows = (num_maps + cols -1)
  plt.figure(figsize=(12, 6))
  for i in range(num_maps):
    plt.subplot(rows, cols, i + 1)
    plt.imshow(fmaps[i], cmap='gray')
    plt.axis('off')
  plt.suptitle("Feature maps")
  plt.show()

# %%
net.eval()
images, labels = next(iter(testloader))
images = images.to(device)
images.requires_grad_()

outputs = net(images)
scores = outputs.gather(1, outputs.argmax(dim=1, keepdim=True))
net.zero_grad()
scores.backward(torch.ones_like(scores))

saliency_maps = images.grad.abs().max(dim=1)[0]


batch_size = 10  # how many images to show
plt.figure(figsize=(16, 4))

for i in range(batch_size):
    img_to_show = images[i].detach().cpu().permute(1, 2, 0).numpy()
    img_to_show = (img_to_show - img_to_show.min()) / (img_to_show.max() - img_to_show.min())
    saliency = saliency_maps[i].detach().cpu()

    plt.subplot(1, batch_size, i+1)
    plt.imshow(img_to_show)
    plt.imshow(saliency, cmap='hot', alpha=0.5)
    plt.axis('off')
plt.suptitle("Saliency Map Overlays")
plt.show()

# %% [markdown]
# ## Model evaluation
#
# Calculate the model accuracy on the test set and print a confusion matrix where the Y-axis represents the real category and the X-axis represents the predicted category. (10 points)

# %%
confusion_matrix = np.zeros([10,10], int)
model_accuracy = 0.0
total_correct = 0
total_images = 0
#############################################################################
# TO DO:                                                                    #
# Define the evaluation loop as demonstrated in the                          #
# documentation and use the confusion matrix to evaluate your model.        #
#############################################################################
net.eval()
device = next(net.parameters()).device

with torch.no_grad():
    for inputs, labels in testloader:
      inputs, labels = inputs.to(device), labels.to(device)
      outputs = net(inputs)

      preds = outputs.argmax(dim=1)

      total_correct += (preds == labels).sum().item()
      total_images += labels.size(0)

      for t, p in zip(labels.view(-1), preds.view(-1)):
          confusion_matrix[t.long(), p.long()] +=1

model_accuracy = 100.0 * total_correct / total_images

#############################################################################
#                             END OF YOUR CODE                              #
#############################################################################
print('Model accuracy on {0} test images: {1:.2f}%'.format(len(testset), model_accuracy))
# Out:
# Model accuracy on 10000 test images: 71.04%

# %%
fig, ax = plt.subplots(1,1,figsize=(8,6))
ax.matshow(confusion_matrix, aspect='auto', vmin=0, vmax=1000, cmap=plt.get_cmap('RdPu'))
plt.ylabel('Actual Category')
plt.yticks(range(10), classes)
plt.xlabel('Predicted Category')
plt.xticks(range(10), classes)
plt.show()

# %% [markdown]
# ##**Question 1:**
# Describe your experiments.
# - Which specific hyperparameters (e.g., LR, Batch Size) or architectural changes (e.g., number of layers, kernel sizes) did you tweak?
# - Did you encounter overfitting or underfitting? How did you solve it?
# - Successes vs. Failures: Describe one configuration that failed or performed poorly, and try to explain why. Then, contrast it with what worked.
# - What was the single most impactful change you made that boosted your accuracy over the 60% threshold?
#    **(5 Points)**
#
# **Your answer:**

# %% [markdown]
# ##**Question 2:**
# What can you learn from the confusion matrix? Why do you need additional evaluation methods other than accuracy? **(5 Points)**
#
# **Your answer:**

# %% [markdown]
# # Part B (60 points)
# # Localization as Regression
#
# In this next part, we will utilize a well-known architecture called ResNet18. This model has been pretrained on ImageNet, a dataset significantly larger and richer than CIFAR10, containing over 1 million images across 1,000 classes.
#
# The Goal: We will use the features extracted by the pretrained ResNet18 to perform a dual task: classifying and localizing images of 🐈 and 🐕.
#
# Why do this?
#
# Using a pretrained network as a building block for new tasks—a technique known as Transfer Learning—is a cornerstone of modern Deep Learning. By leveraging the robust visual features ResNet18 has already learned (like edges, textures, and shapes), we can train a high-performing model for our specific task using a surprisingly small number of images.

# %% [markdown]
# ## ⚠️ Prerequisite: Data Setup
# Before starting Part 2, you must upload the provided data folder to your Google Drive.
#
# 1. Download the data_hw3 folder provided with this assignment.
#
# 2. Upload the entire data_hw3 folder to the root directory of your Google Drive (inside "My Drive").
#
# 3. Mount Drive: Ensure your Drive is mounted in the notebook (run the cell below).
#
# Note: If you upload the folder inside other sub-folders, you will need to adjust the file paths in the code accordingly.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 1. Mount the entire Drive to the standard location
drive.mount('/content/drive')

# 2. Path to the folder you mounted
project_path = '/content/drive/MyDrive/Colab Notebooks/data_hw3' # change if needed

# Add it to the system path if it's not there
if project_path not in sys.path:
    sys.path.append(project_path)

# Verify what is inside the folder (needs to be ['dataloader.py', 'animals'])
print(f"Files found in {project_path}:")
try:
    print(os.listdir(project_path))
except FileNotFoundError:
    print("Error: The path does not exist. Check if the folder name is exactly 'data_hw3'")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Files found in /content/drive/MyDrive/Colab Notebooks/data_hw3:
# ['annotations.html', 'animals', '__pycache__', 'dataloader.py']

# %%
from dataloader import bb_intersection_over_union as calculate_iou
from dataloader import *
from torchvision.models import resnet18, ResNet18_Weights
import matplotlib.patches as patches
import torchvision.models as models
from PIL import Image
import collections
from torchsummary import summary
import time
import copy

# %% [markdown]
# ## load ResNet18
# To load ResNet18 with the pretrained weights, use the following line. You are welcome to try different architectures, however they might require different input sizes or normalization.
#
# The first time you run this cell the weights will be downloaded.

# %%
resnet18 = resnet18(weights=ResNet18_Weights.DEFAULT)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 180MB/s]

# %% [markdown]
# ## Note:
# ResNet takes as input images of size (224,224). We will use PyTorch Transforms to change the size of the images. When ResNet18 was trained on ImageNet, the images were normalized using the mean and standard deviation of the images. In order to properly use the weights, we will use the same normalization.

# %%
data_transforms = {
    'train': transforms.Compose([
        Rescale((224,224)),
        ToTensor(),
        Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # normalizing according to imagenet
    ]),
    'val': transforms.Compose([
        Rescale((224,224)),
        ToTensor(),
        Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}
root_dir = os.path.join(project_path,"animals")
datasets = {x: VOCDetection(root_dir, image_set=x, transform=data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(datasets[x], batch_size=32, shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(datasets[x]) for x in ['train', 'val']}
classes = datasets['train'].classes
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

print(dataset_sizes)
# Out:
# {'train': 636, 'val': 158}

# %%
# Get a batch of training data
sample = next(iter(dataloaders['train']))
print(sample.keys())
# Out:
# dict_keys(['image', 'label', 'bbox'])

# %%
def imshow(img, label, bbox):
    image = np.copy(img[0])
    image = np.transpose(image, (1, 2, 0))
    image *= np.array([0.229, 0.224, 0.225])
    image += np.array([0.485, 0.456, 0.406])
    label = label[0]
    bbox = bbox[0]
    plt.figure();
    fig, ax = plt.subplots(1, figsize=(12,9));
    ax.imshow(image);
    x1, y1, x2, y2 = bbox.numpy().reshape(-1) * 224
    box_w, box_h = np.abs(x2-x1), np.abs(y2-y1)
    bbox = patches.Rectangle((x1, y1), box_w, box_h, linewidth=2,
                             edgecolor='r', facecolor='none');
    ax.add_patch(bbox);
    ax.annotate(classes[label], (x1, y1), color='r', fontsize=14);

imshow(sample['image'],sample['label'],sample['bbox'])
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4305114e-08..1.0].

# %% [markdown]
# **(20 Points)**

# %%
class CNN(nn.Module):
    def __init__(self, num_classes):
        super(CNN, self).__init__()
        #############################################################################
        # TO DO:                                                                    #
        # 1. Load the pretrained ResNet-18 network.                                 #
        # 2. Remove the top fully connected layer so we could use the features of   #
        #    the network and not the only the classification layer which carries    #
        #    significantly less information.                                        #
        #                                                                           #
        # 3. Heads: Define two separate sub-networks (heads) that take the          #
        #    backbone's output features as input:                                   #
        #      a) Classification Head: features -> FC layers -> class scores        #
        #      b) Detection Head:      features -> FC layers -> Bbox coordinates    #
        #                                                                           #
        # Clarification:                                                            #
        # - You are effectively building a multi-task network with a shared         #
        #   backbone and two parallel output branches.                              #
        # - You may choose to freeze the backbone weights or train them.            #
        # - This function has no return value                                       #
        #############################################################################
        backbone = resnet18(pretrained=True)
        self.backbone = nn.Sequential(*list(backbone.children())[:-1])
        self.class_head = nn.Sequential(
            nn.Linear(512, 120),
            nn.ReLU(),
            nn.Linear(120, 84),
            nn.ReLU(),
            nn.Linear(84, num_classes)
            )
        self.bbox_head = nn.Sequential(
            nn.Linear(512, 120),
            nn.ReLU(),
            nn.Linear(120, 84),
            nn.ReLU(),
            nn.Linear(84,4)
        )
        #############################################################################
        #                             END OF YOUR CODE                              #
        #############################################################################

    def forward(self, images):
        #############################################################################
        # TO DO:                                                                    #
        # Define the forward propagation. You need to pass an image through the     #
        # network and extract the feature vector. In this case, when using a        #
        # predefined network, you don't want to change it's weights.                #
        # The rest of the layers you defined should accepts gradients for them to   #
        # improve during training.                                                  #
        # This function returns a class predication and a bounding box coordinates. #
        #############################################################################
        features = self.backbone(images)
        feature_vec = torch.flatten(features, 1)

        c_preds = self.class_head(feature_vec)
        bb_estimate = self.bbox_head(feature_vec)

        return c_preds, bb_estimate
        #############################################################################
        #                             END OF YOUR CODE                              #
        #############################################################################
net = CNN(10).to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))
print(f"Using device: {device}")
# Out:
# Using device: cuda:0
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# ## Guidelines
#
# 1. Complete the `train_model` function in the cell below. This function takes as input the model and additional hyper-parameters, and outputs the best model found on the validation set.
# 2. To babysit the learning process, **you must track the classification accuracy, IoU score and loss on the training and validation datasets and visualize them** (using matplotlib or similar). I have included an implementation of the IoU metric in the file `data_hw3\dataloader.py`.
# 3. Do not perform a massive grid search!!
# 4. Use papers, blogs, MOOCs and online guides to research best hyper-parameters for your model.
# 5. You are encouraged to try Google Colab. If you have an CUDA capable GPU at home - you are welcome to use it.
# 5. **Include only your chosen architecture**. During experimentation, you may add as many cells as you need. Make sure to delete them before submission.
# 6. Training large neural networks may take a while. Make sure your code runs reasonably fast (~15 minutes on CPU and ~5 minutes on GPU).
# 7. Try to reach at least 90% classification accuracy and a IOU score of at least 0.60 on the validation set.
# 8. **In order to get full marks for this section explain the results and include visualizations.**.
# 9. You are given a general skeleton for the training function. Feel free to use any different structure.
#
# **(30 Points)**

# %%
def train_model(model, criterion_cls, criterion_bbox, optimizer, scheduler=None, num_epochs=5):
    since = time.time()
    best_model_wts = copy.deepcopy(model.state_dict()) # this is how a model is copied
    best_acc = 0.0

    # added - track metrics
    history = {
        'train_loss': [], 'val_loss': [],
        'train_acc': [], 'val_acc': [],
        'train_iou': [], 'val_iou': []
    }

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0   # total loss of the network at each epoch
            running_corrects = 0 # number of correct predictions
            iou = 0.0            # IoU score

            # Iterate over data.
            for sample in dataloaders[phase]:
                #############################################################################
                # TO DO:                                                                    #
                # Extract the data from the dataloader, calculate the predictions of your   #
                # network and calculate the loss of the classification and bounding box     #
                # prediction. When in training mode, back-prop and update the weights.      #
                # At each epoch, calculate the test and train accuracy and IoU.             #
                # This function returns the best model in terms of accuracy.                #
                #############################################################################

                #print(sample)
                images = sample.get('image')
                labels = sample.get('label')
                bboxes = sample.get('bbox')
                images, labels, bboxes = images.to(device), labels.to(device), bboxes.to(device)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase=='train'):
                    c_preds, bb_estimates = model(images)
                    print("bb_estimate", bb_estimates[0])
                    print("Actual Box", bboxes[0])
                    loss_cls = criterion_cls(c_preds, labels)
                    loss_bbox = criterion_bbox(bb_estimates, bboxes)
                    loss = loss_cls + 10*loss_bbox

                    if phase == 'train':
                      loss.backward()
                      optimizer.step()

                running_loss += loss.item()*images.size(0)
                _, preds = torch.max(c_preds, 1)
                running_corrects += torch.sum(preds == labels).item()
                batch_size = bb_estimates.size(0)
                batch_iou = 0.0

                for i in range(batch_size):
                  batch_iou += calculate_iou(bb_estimates[i], bboxes[i])

                iou += batch_iou / batch_size
                # The above for loop can be vectorised - deal with it later




                #############################################################################
                #                             END OF YOUR CODE                              #
                #############################################################################

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = torch.tensor(running_corrects, dtype=torch.float32) / dataset_sizes[phase]
            iou = iou / dataset_sizes[phase]

            # added - log metrics
            history[f'{phase}_loss'].append(epoch_loss)
            history[f'{phase}_acc'].append(epoch_acc.item())
            history[f'{phase}_iou'].append(iou)


            print('{} Loss: {:.4f}  |  Acc: {:.4f}  |  IOU: {:.4f}'.format(
                phase, epoch_loss, epoch_acc, iou))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, history

# %% [markdown]
# Choose your optimizer and the loss functions for the classification and bounding box regression.

# %%
cnn = CNN(2)
cnn = cnn.to(device)

criterion_cls = None
criterion_bbox = None
optimizer = None
#############################################################################
#                           START OF YOUR CODE                              #
#############################################################################

for param in cnn.backbone.parameters():
  param.requires_grad = False

criterion_cls = nn.CrossEntropyLoss()
criterion_bbox = nn.SmoothL1Loss()

optimizer = optimizer = torch.optim.Adam(
    list(cnn.class_head.parameters()) + list(cnn.bbox_head.parameters()),
    lr=1e-3, weight_decay=1e-4
)

scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)
#############################################################################
#                             END OF YOUR CODE                              #
#############################################################################
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
best_model,history = train_model(cnn, criterion_cls, criterion_bbox, optimizer, num_epochs=10)
# Out:
# Epoch 1/10
# ----------
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# bb_estimate tensor([-0.1366,  0.1037,  0.0509, -0.0241], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2400, 0.0030, 0.8820, 0.8408], device='cuda:0')
# bb_estimate tensor([-0.0241,  0.1992,  0.2813,  0.1983], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4920, 0.1920, 0.7940, 0.5707], device='cuda:0')
# bb_estimate tensor([0.1463, 0.2058, 0.7356, 0.5707], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2480, 0.2027, 0.7800, 0.7120], device='cuda:0')
# bb_estimate tensor([0.4598, 0.2588, 1.0850, 0.8542], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.5347, 0.1533, 0.7812, 0.5167], device='cuda:0')
# bb_estimate tensor([0.5640, 0.1378, 1.1150, 0.9658], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2407, 0.1820, 0.5955, 0.5000], device='cuda:0')
# bb_estimate tensor([0.4546, 0.1239, 0.7634, 0.6605], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4870, 0.0480, 0.7435, 0.2926], device='cuda:0')
# bb_estimate tensor([0.4512, 0.0446, 0.7944, 0.6105], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3267, 0.0756, 0.7100, 0.6044], device='cuda:0')
# bb_estimate tensor([0.2412, 0.0596, 0.5767, 0.4314], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.0240, 0.2560, 0.8480, 0.7360], device='cuda:0')
# bb_estimate tensor([0.1939, 0.0913, 0.5645, 0.3713], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2282, 0.2540, 0.6676, 0.5720], device='cuda:0')
# bb_estimate tensor([0.2303, 0.2110, 0.6429, 0.5505], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3140, 0.0090, 0.5880, 0.4474], device='cuda:0')
# bb_estimate tensor([0.1884, 0.1325, 0.5567, 0.4980], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.5280, 0.0453, 0.8060, 0.4053], device='cuda:0')
# bb_estimate tensor([0.1595, 0.2727, 0.6339, 0.5086], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3940, 0.2747, 0.7600, 0.6560], device='cuda:0')
# bb_estimate tensor([0.1658, 0.2409, 0.6174, 0.5575], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4217, 0.2640, 0.6928, 0.4160], device='cuda:0')
# bb_estimate tensor([0.2561, 0.2385, 0.5926, 0.5940], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.6040, 0.1093, 0.9440, 0.5600], device='cuda:0')
# bb_estimate tensor([0.4018, 0.2402, 0.8147, 0.7732], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4760, 0.1417, 0.7820, 0.4768], device='cuda:0')
# bb_estimate tensor([0.3057, 0.1484, 0.6454, 0.5997], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3180, 0.1622, 0.5320, 0.4925], device='cuda:0')
# bb_estimate tensor([0.3010, 0.2381, 0.7889, 0.6353], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4340, 0.2587, 0.7400, 0.5627], device='cuda:0')
# bb_estimate tensor([0.2786, 0.1032, 0.6850, 0.5365], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2420, 0.0613, 0.8020, 0.6987], device='cuda:0')
# bb_estimate tensor([0.3645, 0.0719, 0.7679, 0.5250], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3240, 0.1867, 0.7260, 0.5813], device='cuda:0')
# bb_estimate tensor([0.3391, 0.0446, 0.7343, 0.5104], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.5480, 0.1990, 0.7560, 0.4029], device='cuda:0')
# train Loss: 0.6250  |  Acc: 0.8648  |  IOU: 0.0200
# bb_estimate tensor([0.4054, 0.1096, 0.7830, 0.5176], device='cuda:0')
# Actual Box tensor([0.2840, 0.1760, 0.4700, 0.5280], device='cuda:0')
# bb_estimate tensor([0.2984, 0.0959, 0.6426, 0.4844], device='cuda:0')
# Actual Box tensor([0.1051, 0.1240, 0.5165, 0.4080], device='cuda:0')
# bb_estimate tensor([0.2765, 0.0490, 0.7436, 0.5289], device='cuda:0')
# Actual Box tensor([0.3880, 0.1712, 0.6320, 0.5586], device='cuda:0')
# bb_estimate tensor([0.2954, 0.1376, 0.7883, 0.5485], device='cuda:0')
# Actual Box tensor([0.3260, 0.0299, 0.8020, 0.7814], device='cuda:0')
# bb_estimate tensor([ 0.3175, -0.0059,  0.7647,  0.4974], device='cuda:0')
# Actual Box tensor([0.3300, 0.1553, 0.7520, 0.5963], device='cuda:0')
# val Loss: 0.1801  |  Acc: 0.9810  |  IOU: 0.0231
# Epoch 2/10
# ----------
# bb_estimate tensor([0.2909, 0.0615, 0.6875, 0.4334], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.0280, 0.0378, 0.7700, 0.8227], device='cuda:0')
# bb_estimate tensor([0.1702, 0.0967, 0.6115, 0.4640], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3660, 0.1772, 0.8780, 0.7748], device='cuda:0')
# bb_estimate tensor([0.2258, 0.1502, 0.7755, 0.5663], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3700, 0.2000, 0.6220, 0.4987], device='cuda:0')
# bb_estimate tensor([0.2414, 0.1742, 0.6543, 0.5490], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2960, 0.1540, 0.8320, 0.5540], device='cuda:0')
# bb_estimate tensor([0.2658, 0.1513, 0.6496, 0.5195], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.0500, 0.5513, 0.2467, 0.7833], device='cuda:0')
# bb_estimate tensor([0.2695, 0.2526, 0.7028, 0.6462], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4460, 0.3093, 0.7000, 0.6027], device='cuda:0')
# bb_estimate tensor([0.2461, 0.2348, 0.6024, 0.5769], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4920, 0.1920, 0.7940, 0.5707], device='cuda:0')
# bb_estimate tensor([0.3063, 0.2493, 0.6539, 0.6630], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.1760, 0.1947, 0.4660, 0.5387], device='cuda:0')
# bb_estimate tensor([0.1890, 0.1774, 0.5864, 0.6084], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3660, 0.1802, 0.8020, 0.7688], device='cuda:0')
# bb_estimate tensor([0.3750, 0.3339, 0.7211, 0.7546], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3596, 0.3300, 0.6689, 0.5660], device='cuda:0')
# bb_estimate tensor([0.4024, 0.1599, 0.6968, 0.5443], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3233, 0.2517, 0.6400, 0.6259], device='cuda:0')
# bb_estimate tensor([0.3615, 0.0737, 0.6177, 0.4889], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4000, 0.3000, 0.6139, 0.5963], device='cuda:0')
# bb_estimate tensor([0.2867, 0.1903, 0.7192, 0.6220], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3100, 0.0027, 0.7340, 0.4880], device='cuda:0')
# bb_estimate tensor([0.3088, 0.1846, 0.7429, 0.5826], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4080, 0.2453, 0.5840, 0.4933], device='cuda:0')
# bb_estimate tensor([0.3765, 0.1653, 0.7061, 0.5593], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4020, 0.3493, 0.6760, 0.5760], device='cuda:0')
# bb_estimate tensor([0.3213, 0.0277, 0.6239, 0.4276], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4620, 0.2613, 0.6460, 0.4625], device='cuda:0')
# bb_estimate tensor([0.1416, 0.0980, 0.7299, 0.6679], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3000, 0.0427, 1.0000, 0.8667], device='cuda:0')
# bb_estimate tensor([0.2970, 0.1381, 0.6678, 0.4768], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.6875, 0.3351, 0.9333, 0.6546], device='cuda:0')
# bb_estimate tensor([0.2850, 0.2038, 0.7552, 0.5386], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3174, 0.3140, 0.6228, 0.5100], device='cuda:0')
# bb_estimate tensor([0.3319, 0.1933, 0.8163, 0.5196], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2680, 0.2613, 0.6740, 0.7120], device='cuda:0')
# train Loss: 0.1875  |  Acc: 0.9748  |  IOU: 0.0226
# bb_estimate tensor([0.2233, 0.1392, 0.6527, 0.4965], device='cuda:0')
# Actual Box tensor([0.1780, 0.0420, 0.5960, 0.6611], device='cuda:0')
# bb_estimate tensor([0.3861, 0.2510, 0.7502, 0.6296], device='cuda:0')
# Actual Box tensor([0.1432, 0.4040, 0.5000, 0.6460], device='cuda:0')
# bb_estimate tensor([0.2963, 0.1511, 0.7426, 0.5420], device='cuda:0')
# Actual Box tensor([0.4740, 0.2693, 0.7460, 0.6053], device='cuda:0')
# bb_estimate tensor([0.2790, 0.1040, 0.6799, 0.4379], device='cuda:0')
# Actual Box tensor([0.2872, 0.0156, 0.8723, 0.3244], device='cuda:0')
# bb_estimate tensor([0.2317, 0.1894, 0.8299, 0.6885], device='cuda:0')
# Actual Box tensor([0.2960, 0.2382, 0.6720, 0.6593], device='cuda:0')
# val Loss: 0.1365  |  Acc: 0.9873  |  IOU: 0.0233
# Epoch 3/10
# ----------
# bb_estimate tensor([0.2503, 0.1051, 0.7154, 0.4955], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3160, 0.0085, 0.7680, 0.5199], device='cuda:0')
# bb_estimate tensor([0.3629, 0.1802, 0.7487, 0.6312], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4075, 0.1200, 0.8850, 0.4400], device='cuda:0')
# bb_estimate tensor([0.3866, 0.2107, 0.7727, 0.6384], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2060, 0.3547, 0.5060, 0.7200], device='cuda:0')
# bb_estimate tensor([0.2903, 0.2037, 0.5652, 0.5186], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4583, 0.2786, 0.8333, 0.6321], device='cuda:0')
# bb_estimate tensor([0.2322, 0.1258, 0.7461, 0.7152], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3100, 0.0198, 0.9580, 0.9632], device='cuda:0')
# bb_estimate tensor([0.3496, 0.2125, 0.8068, 0.7947], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3800, 0.1142, 0.8400, 0.7958], device='cuda:0')
# bb_estimate tensor([0.2903, 0.1486, 0.6479, 0.7475], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.1680, 0.2583, 0.4080, 0.5886], device='cuda:0')
# bb_estimate tensor([0.1670, 0.1014, 0.5860, 0.6194], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.0759, 0.2120, 0.7072, 0.6860], device='cuda:0')
# bb_estimate tensor([0.2398, 0.1119, 0.6637, 0.6472], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.0940, 0.4000, 0.5520, 0.8080], device='cuda:0')
# bb_estimate tensor([0.3264, 0.0925, 0.6230, 0.4677], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4688, 0.2235, 0.6297, 0.4612], device='cuda:0')
# bb_estimate tensor([0.1690, 0.0655, 0.6361, 0.5168], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.0680, 0.1150, 0.4460, 0.6578], device='cuda:0')
# bb_estimate tensor([0.1709, 0.0989, 0.6376, 0.5974], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2920, 0.1173, 0.7380, 0.6747], device='cuda:0')
# bb_estimate tensor([0.2259, 0.1121, 0.5510, 0.3996], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.5133, 0.2400, 0.6867, 0.4850], device='cuda:0')
# bb_estimate tensor([0.3415, 0.2029, 0.7600, 0.5263], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2880, 0.1440, 0.5840, 0.5653], device='cuda:0')
# bb_estimate tensor([0.2950, 0.1835, 0.5297, 0.3437], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.1033, 0.0613, 0.2900, 0.3988], device='cuda:0')
# bb_estimate tensor([0.3529, 0.1834, 0.6484, 0.4194], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4880, 0.1760, 0.6760, 0.3840], device='cuda:0')
# bb_estimate tensor([0.3512, 0.1316, 0.7098, 0.4102], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4500, 0.0541, 0.8350, 0.3153], device='cuda:0')
# bb_estimate tensor([0.2131, 0.1338, 0.7318, 0.6591], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.1952, 0.0960, 0.8529, 0.5320], device='cuda:0')
# bb_estimate tensor([0.3718, 0.2013, 0.7073, 0.5279], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4620, 0.0773, 0.7600, 0.5851], device='cuda:0')
# bb_estimate tensor([0.2882, 0.1241, 0.6715, 0.5720], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.1440, 0.2544, 0.4340, 0.5536], device='cuda:0')
# train Loss: 0.1429  |  Acc: 0.9811  |  IOU: 0.0235
# bb_estimate tensor([0.4473, 0.2150, 0.5781, 0.5186], device='cuda:0')
# Actual Box tensor([0.3780, 0.2053, 0.6360, 0.5653], device='cuda:0')
# bb_estimate tensor([0.3744, 0.1941, 0.7103, 0.6665], device='cuda:0')
# Actual Box tensor([0.4280, 0.0811, 0.6480, 0.3844], device='cuda:0')
# bb_estimate tensor([0.2865, 0.2036, 0.5150, 0.4873], device='cuda:0')
# Actual Box tensor([0.4040, 0.1253, 0.7220, 0.5280], device='cuda:0')
# bb_estimate tensor([0.3013, 0.1946, 0.5579, 0.5351], device='cuda:0')
# Actual Box tensor([0.2102, 0.0940, 0.7027, 0.4520], device='cuda:0')
# bb_estimate tensor([0.1886, 0.1012, 0.8623, 0.9069], device='cuda:0')
# Actual Box tensor([0.0062, 0.0040, 0.9649, 0.9920], device='cuda:0')
# val Loss: 0.1744  |  Acc: 0.9684  |  IOU: 0.0236
# Epoch 4/10
# ----------
# bb_estimate tensor([0.3946, 0.1828, 0.6448, 0.4745], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2540, 0.2293, 0.4420, 0.5013], device='cuda:0')
# bb_estimate tensor([0.3695, 0.1237, 0.6812, 0.5737], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2089, 0.2833, 0.4489, 0.5167], device='cuda:0')
# bb_estimate tensor([0.1947, 0.1853, 0.7749, 0.8486], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.0560, 0.0933, 0.8040, 0.9520], device='cuda:0')
# bb_estimate tensor([0.3182, 0.1841, 0.7300, 0.6260], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4053, 0.2360, 0.6373, 0.4140], device='cuda:0')
# bb_estimate tensor([0.1970, 0.1498, 0.5947, 0.5927], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2560, 0.1387, 0.5900, 0.5493], device='cuda:0')
# bb_estimate tensor([0.2465, 0.1004, 0.8120, 0.7039], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4720, 0.0755, 0.7440, 0.4279], device='cuda:0')
# bb_estimate tensor([0.2758, 0.2326, 0.6371, 0.5817], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.1960, 0.4507, 0.6000, 0.9547], device='cuda:0')
# bb_estimate tensor([0.3655, 0.1562, 0.6886, 0.3853], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3562, 0.0829, 0.8455, 0.4057], device='cuda:0')
# bb_estimate tensor([0.3826, 0.1563, 0.8247, 0.5797], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4932, 0.1040, 0.9918, 0.4760], device='cuda:0')
# bb_estimate tensor([0.2660, 0.1751, 0.8836, 0.7764], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3573, 0.4140, 0.8747, 0.7860], device='cuda:0')
# bb_estimate tensor([0.1136, 0.0731, 0.7695, 0.6952], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.0759, 0.2120, 0.7072, 0.6860], device='cuda:0')
# bb_estimate tensor([0.3913, 0.1042, 0.6999, 0.5406], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2680, 0.2021, 0.4420, 0.4843], device='cuda:0')
# bb_estimate tensor([0.3520, 0.1549, 0.6827, 0.4558], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2733, 0.2540, 0.5616, 0.4500], device='cuda:0')
# bb_estimate tensor([0.2422, 0.0631, 0.7231, 0.5740], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3200, 0.1750, 0.6333, 0.5900], device='cuda:0')
# bb_estimate tensor([0.1360, 0.0291, 0.8262, 0.7176], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.1940, 0.0020, 0.9532, 0.4840], device='cuda:0')
# bb_estimate tensor([0.2013, 0.1340, 0.8383, 0.8302], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.1960, 0.1471, 0.6900, 0.8589], device='cuda:0')
# bb_estimate tensor([0.2678, 0.1383, 0.6174, 0.4724], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3240, 0.1867, 0.7260, 0.5813], device='cuda:0')
# bb_estimate tensor([0.4406, 0.3115, 0.4684, 0.3991], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4060, 0.2883, 0.5580, 0.4805], device='cuda:0')
# bb_estimate tensor([0.4085, 0.2415, 0.6517, 0.4961], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2060, 0.3547, 0.5060, 0.7200], device='cuda:0')
# bb_estimate tensor([0.4126, 0.1665, 0.6912, 0.5103], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.1300, 0.0861, 0.3633, 0.3558], device='cuda:0')
# train Loss: 0.1122  |  Acc: 0.9921  |  IOU: 0.0238
# bb_estimate tensor([0.3033, 0.1806, 0.7997, 0.6896], device='cuda:0')
# Actual Box tensor([0.2160, 0.4474, 0.3980, 0.6877], device='cuda:0')
# bb_estimate tensor([0.2937, 0.1947, 0.6947, 0.6012], device='cuda:0')
# Actual Box tensor([0.1826, 0.1340, 0.4701, 0.3500], device='cuda:0')
# bb_estimate tensor([0.4112, 0.2289, 0.6584, 0.5043], device='cuda:0')
# Actual Box tensor([0.2520, 0.1467, 0.4580, 0.4293], device='cuda:0')
# bb_estimate tensor([0.3006, 0.1689, 0.7272, 0.5909], device='cuda:0')
# Actual Box tensor([0.3540, 0.0243, 0.7220, 0.6469], device='cuda:0')
# bb_estimate tensor([0.2015, 0.1264, 0.7687, 0.7115], device='cuda:0')
# Actual Box tensor([0.3688, 0.0412, 0.8720, 0.7390], device='cuda:0')
# val Loss: 0.1382  |  Acc: 0.9873  |  IOU: 0.0230
# Epoch 5/10
# ----------
# bb_estimate tensor([0.2683, 0.2179, 0.6745, 0.7134], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3100, 0.3754, 0.5120, 0.6787], device='cuda:0')
# bb_estimate tensor([0.1981, 0.1173, 0.8322, 0.8357], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3200, 0.0627, 0.6800, 0.6866], device='cuda:0')
# bb_estimate tensor([0.3985, 0.1878, 0.7794, 0.6519], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.1993, 0.0720, 0.5876, 0.3300], device='cuda:0')
# bb_estimate tensor([0.2578, 0.2221, 0.8573, 0.8532], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2000, 0.1227, 0.6540, 0.8053], device='cuda:0')
# bb_estimate tensor([0.3320, 0.1571, 0.5924, 0.4347], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2700, 0.2044, 0.5700, 0.5689], device='cuda:0')
# bb_estimate tensor([0.3450, 0.2086, 0.4751, 0.3762], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3880, 0.4048, 0.5120, 0.5710], device='cuda:0')
# bb_estimate tensor([0.3705, 0.1315, 0.6216, 0.5228], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3667, 0.1244, 0.6033, 0.4756], device='cuda:0')
# bb_estimate tensor([0.2574, 0.1333, 0.6331, 0.5644], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2440, 0.2480, 0.6520, 0.7093], device='cuda:0')
# bb_estimate tensor([0.1456, 0.1174, 0.6789, 0.6160], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.1700, 0.0853, 0.8240, 0.8320], device='cuda:0')
# bb_estimate tensor([0.3239, 0.1951, 0.6993, 0.6162], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3140, 0.0090, 0.5880, 0.4474], device='cuda:0')
# bb_estimate tensor([0.3216, 0.2017, 0.7775, 0.6476], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4340, 0.2725, 0.6360, 0.5269], device='cuda:0')
# bb_estimate tensor([0.3196, 0.2228, 0.7169, 0.6113], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2040, 0.3627, 0.6260, 0.8453], device='cuda:0')
# bb_estimate tensor([0.3995, 0.1695, 0.6914, 0.6062], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4433, 0.0080, 0.7267, 0.4177], device='cuda:0')
# bb_estimate tensor([0.4194, 0.1337, 0.7884, 0.6034], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.5280, 0.0453, 0.8060, 0.4053], device='cuda:0')
# bb_estimate tensor([0.3490, 0.1971, 0.5824, 0.5371], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4027, 0.3320, 0.6640, 0.5260], device='cuda:0')
# bb_estimate tensor([0.3527, 0.2113, 0.5644, 0.4622], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3400, 0.1556, 0.5933, 0.5067], device='cuda:0')
# bb_estimate tensor([0.2500, 0.1153, 0.6808, 0.5316], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.1856, 0.3720, 0.6826, 0.7300], device='cuda:0')
# bb_estimate tensor([0.2724, 0.1812, 0.6176, 0.4549], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.1400, 0.2220, 0.4756, 0.5000], device='cuda:0')
# bb_estimate tensor([0.1522, 0.2202, 0.6879, 0.6825], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.0020, 0.1440, 0.7520, 0.6960], device='cuda:0')
# bb_estimate tensor([0.1490, 0.1263, 0.8259, 0.8251], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.0271, 0.0201, 0.5864, 0.5886], device='cuda:0')
# train Loss: 0.1207  |  Acc: 0.9874  |  IOU: 0.0240
# bb_estimate tensor([0.3740, 0.1859, 0.6882, 0.6243], device='cuda:0')
# Actual Box tensor([0.1033, 0.1378, 0.3467, 0.5289], device='cuda:0')
# bb_estimate tensor([0.2086, 0.0906, 0.8288, 0.6925], device='cuda:0')
# Actual Box tensor([0.3780, 0.1544, 0.8360, 0.7468], device='cuda:0')
# bb_estimate tensor([0.1335, 0.1973, 0.7913, 0.8290], device='cuda:0')
# Actual Box tensor([0.2980, 0.1527, 0.7760, 0.8383], device='cuda:0')
# bb_estimate tensor([0.2088, 0.1679, 0.7690, 0.5838], device='cuda:0')
# Actual Box tensor([0.1351, 0.1620, 0.8408, 0.5140], device='cuda:0')
# bb_estimate tensor([0.0294, 0.0775, 0.8048, 0.7696], device='cuda:0')
# Actual Box tensor([0.0500, 0.0030, 0.6620, 0.8318], device='cuda:0')
# val Loss: 0.1248  |  Acc: 0.9873  |  IOU: 0.0235
# Epoch 6/10
# ----------
# bb_estimate tensor([0.2673, 0.2287, 0.6509, 0.6084], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3174, 0.3140, 0.6228, 0.5100], device='cuda:0')
# bb_estimate tensor([0.2141, 0.0882, 0.7614, 0.6455], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2600, 0.1618, 0.5620, 0.6445], device='cuda:0')
# bb_estimate tensor([0.2935, 0.0982, 0.8280, 0.7158], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4833, 0.1067, 0.8233, 0.5867], device='cuda:0')
# bb_estimate tensor([0.4417, 0.1904, 0.7662, 0.6073], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4500, 0.2080, 0.7620, 0.7387], device='cuda:0')
# bb_estimate tensor([0.5194, 0.2487, 0.7192, 0.5568], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.6300, 0.1600, 0.8920, 0.5840], device='cuda:0')
# bb_estimate tensor([0.3050, 0.1312, 0.9207, 0.7155], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.0841, 0.1620, 0.9760, 0.7600], device='cuda:0')
# bb_estimate tensor([0.2603, 0.1787, 0.6367, 0.5104], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.0900, 0.1729, 0.5260, 0.5588], device='cuda:0')
# bb_estimate tensor([0.2810, 0.0578, 0.6215, 0.5406], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3400, 0.2489, 0.6600, 0.7911], device='cuda:0')
# bb_estimate tensor([0.2460, 0.0900, 0.6183, 0.5340], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.0680, 0.1381, 0.3780, 0.6577], device='cuda:0')
# bb_estimate tensor([0.0930, 0.0229, 0.8461, 0.8183], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2460, 0.0351, 0.7340, 0.6550], device='cuda:0')
# bb_estimate tensor([0.1054, 0.0750, 0.6831, 0.5925], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.1886, 0.0920, 0.8114, 0.4800], device='cuda:0')
# bb_estimate tensor([0.3240, 0.1692, 0.4683, 0.3951], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.1620, 0.0904, 0.3320, 0.3855], device='cuda:0')
# bb_estimate tensor([0.3115, 0.2163, 0.6817, 0.5073], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4053, 0.2360, 0.6373, 0.4140], device='cuda:0')
# bb_estimate tensor([0.3153, 0.2660, 0.7217, 0.7934], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2320, 0.1682, 0.6100, 0.7207], device='cuda:0')
# bb_estimate tensor([0.3752, 0.2282, 0.6510, 0.5615], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4280, 0.1460, 0.8700, 0.5380], device='cuda:0')
# bb_estimate tensor([0.3309, 0.2453, 0.4672, 0.4480], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.0500, 0.5513, 0.2467, 0.7833], device='cuda:0')
# bb_estimate tensor([0.2890, 0.1691, 0.7507, 0.6524], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2420, 0.0613, 0.8020, 0.6987], device='cuda:0')
# bb_estimate tensor([0.3904, 0.1617, 0.6275, 0.5097], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3700, 0.1360, 0.6500, 0.4907], device='cuda:0')
# bb_estimate tensor([0.3702, 0.2636, 0.6473, 0.5542], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3609, 0.6150, 0.6729, 0.8200], device='cuda:0')
# bb_estimate tensor([0.1634, 0.0551, 0.7928, 0.6817], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.0240, 0.2560, 0.8480, 0.7360], device='cuda:0')
# train Loss: 0.0985  |  Acc: 0.9953  |  IOU: 0.0241
# bb_estimate tensor([0.3581, 0.0681, 0.7098, 0.5213], device='cuda:0')
# Actual Box tensor([0.4200, 0.2312, 0.5320, 0.4835], device='cuda:0')
# bb_estimate tensor([0.2572, 0.1028, 1.0072, 0.7951], device='cuda:0')
# Actual Box tensor([0.0080, 0.0320, 0.7500, 0.6140], device='cuda:0')
# bb_estimate tensor([0.3149, 0.0451, 0.7009, 0.6353], device='cuda:0')
# Actual Box tensor([0.2580, 0.1813, 0.5340, 0.5573], device='cuda:0')
# bb_estimate tensor([0.1123, 0.0273, 0.8275, 0.7779], device='cuda:0')
# Actual Box tensor([0.1920, 0.0873, 0.7200, 0.7620], device='cuda:0')
# bb_estimate tensor([0.2815, 0.0193, 0.6897, 0.4631], device='cuda:0')
# Actual Box tensor([0.2000, 0.0633, 0.7122, 0.5033], device='cuda:0')
# val Loss: 0.1643  |  Acc: 0.9747  |  IOU: 0.0241
# Epoch 7/10
# ----------
# bb_estimate tensor([0.2956, 0.1177, 0.7760, 0.6190], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4020, 0.3493, 0.6760, 0.5760], device='cuda:0')
# bb_estimate tensor([0.2026, 0.1017, 0.7362, 0.5429], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.1688, 0.0780, 0.6104, 0.4800], device='cuda:0')
# bb_estimate tensor([0.2827, 0.1429, 0.6338, 0.4910], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2400, 0.1680, 0.5280, 0.5200], device='cuda:0')
# bb_estimate tensor([0.1563, 0.0915, 0.8496, 0.7503], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.1940, 0.0020, 0.9532, 0.4840], device='cuda:0')
# bb_estimate tensor([0.2874, 0.1359, 0.4341, 0.3250], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.1040, 0.1267, 0.2940, 0.4124], device='cuda:0')
# bb_estimate tensor([0.1600, 0.1980, 0.8058, 0.7684], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.1467, 0.0560, 0.7307, 0.5700], device='cuda:0')
# bb_estimate tensor([0.2987, 0.2557, 0.6089, 0.5212], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.1448, 0.5673, 0.4044, 0.7473], device='cuda:0')
# bb_estimate tensor([0.2146, 0.1211, 0.7102, 0.5742], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.0693, 0.0200, 0.8812, 0.6333], device='cuda:0')
# bb_estimate tensor([0.1432, 0.0816, 0.6904, 0.6000], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2020, 0.0901, 0.7520, 0.8318], device='cuda:0')
# bb_estimate tensor([0.3625, 0.1810, 0.5560, 0.4438], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3627, 0.1000, 0.7840, 0.3420], device='cuda:0')
# bb_estimate tensor([0.1817, 0.0523, 0.6620, 0.5649], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.1300, 0.1717, 0.5200, 0.6027], device='cuda:0')
# bb_estimate tensor([0.2679, 0.1399, 0.6947, 0.6935], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2840, 0.1467, 0.7960, 0.8133], device='cuda:0')
# bb_estimate tensor([0.2232, 0.1622, 0.6698, 0.6034], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.0900, 0.1729, 0.5260, 0.5588], device='cuda:0')
# bb_estimate tensor([0.3452, 0.1795, 0.7676, 0.7165], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3140, 0.0090, 0.5880, 0.4474], device='cuda:0')
# bb_estimate tensor([0.2523, 0.1443, 0.9659, 0.8420], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.0450, 0.2360, 0.8258, 0.7900], device='cuda:0')
# bb_estimate tensor([0.2739, 0.1413, 0.7508, 0.5976], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3040, 0.0389, 0.7060, 0.5449], device='cuda:0')
# bb_estimate tensor([0.2530, 0.1339, 0.7351, 0.6665], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.1700, 0.1920, 0.7340, 0.8240], device='cuda:0')
# bb_estimate tensor([0.2876, 0.2040, 0.7541, 0.7487], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2980, 0.4024, 0.5820, 0.8589], device='cuda:0')
# bb_estimate tensor([0.1938, 0.2206, 0.8254, 0.8360], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.1940, 0.2373, 0.9380, 0.9360], device='cuda:0')
# bb_estimate tensor([0.2038, 0.0868, 0.6963, 0.5667], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2380, 0.0693, 0.7060, 0.5787], device='cuda:0')
# train Loss: 0.1291  |  Acc: 0.9811  |  IOU: 0.0242
# bb_estimate tensor([0.2875, 0.1841, 0.5298, 0.4738], device='cuda:0')
# Actual Box tensor([0.4000, 0.0933, 0.5600, 0.3200], device='cuda:0')
# bb_estimate tensor([0.1903, 0.2561, 0.7538, 0.7892], device='cuda:0')
# Actual Box tensor([0.2980, 0.1527, 0.7760, 0.8383], device='cuda:0')
# bb_estimate tensor([0.3905, 0.1748, 0.6083, 0.4981], device='cuda:0')
# Actual Box tensor([0.5100, 0.2160, 0.7160, 0.5813], device='cuda:0')
# bb_estimate tensor([0.2911, 0.2114, 0.6022, 0.4813], device='cuda:0')
# Actual Box tensor([0.3083, 0.2300, 0.6117, 0.4900], device='cuda:0')
# bb_estimate tensor([0.3203, 0.1602, 0.6747, 0.6185], device='cuda:0')
# Actual Box tensor([0.2960, 0.1520, 0.6140, 0.5947], device='cuda:0')
# val Loss: 0.1149  |  Acc: 0.9810  |  IOU: 0.0238
# Epoch 8/10
# ----------
# bb_estimate tensor([0.3042, 0.2219, 0.6003, 0.5360], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2875, 0.1941, 0.5038, 0.4697], device='cuda:0')
# bb_estimate tensor([0.2897, 0.1623, 0.8162, 0.4862], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3562, 0.0829, 0.8455, 0.4057], device='cuda:0')
# bb_estimate tensor([0.3063, 0.2288, 0.5755, 0.5985], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.1680, 0.2583, 0.4080, 0.5886], device='cuda:0')
# bb_estimate tensor([0.2806, 0.1832, 0.7489, 0.5288], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3795, 0.1580, 0.8313, 0.4040], device='cuda:0')
# bb_estimate tensor([0.2252, 0.2438, 0.8470, 0.7948], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3480, 0.4162, 0.7720, 0.8563], device='cuda:0')
# bb_estimate tensor([0.3587, 0.1957, 0.5771, 0.5750], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4220, 0.2027, 0.7600, 0.5627], device='cuda:0')
# bb_estimate tensor([0.4156, 0.2804, 0.6757, 0.5977], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.1300, 0.4933, 0.3760, 0.7573], device='cuda:0')
# bb_estimate tensor([0.2901, 0.0155, 0.7523, 0.5696], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3400, 0.1422, 0.7000, 0.6889], device='cuda:0')
# bb_estimate tensor([0.1703, 0.0456, 0.6572, 0.6695], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2080, 0.0453, 0.6540, 0.6347], device='cuda:0')
# bb_estimate tensor([0.1302, 0.0724, 0.7050, 0.5719], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2810, 0.0558, 0.8058, 0.5923], device='cuda:0')
# bb_estimate tensor([0.3170, 0.1247, 0.5497, 0.4224], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.0625, 0.0251, 0.4375, 0.5078], device='cuda:0')
# bb_estimate tensor([0.3230, 0.1558, 0.6044, 0.4059], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4800, 0.0333, 0.7033, 0.3542], device='cuda:0')
# bb_estimate tensor([0.3936, 0.1745, 0.7629, 0.4827], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4120, 0.0027, 0.7080, 0.3467], device='cuda:0')
# bb_estimate tensor([0.4126, 0.1574, 0.8054, 0.6610], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4420, 0.0293, 0.8180, 0.5200], device='cuda:0')
# bb_estimate tensor([0.3770, 0.2862, 0.8114, 0.7117], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4020, 0.3493, 0.6760, 0.5760], device='cuda:0')
# bb_estimate tensor([0.3047, 0.1456, 0.6338, 0.5962], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2920, 0.1173, 0.7380, 0.6747], device='cuda:0')
# bb_estimate tensor([0.3690, 0.0738, 0.7135, 0.5623], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2380, 0.0613, 0.6680, 0.7333], device='cuda:0')
# bb_estimate tensor([0.3235, 0.1027, 0.6987, 0.5749], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2900, 0.0978, 0.7100, 0.6667], device='cuda:0')
# bb_estimate tensor([0.1043, 0.0344, 0.8233, 0.8819], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.0860, 0.1201, 0.6000, 0.8739], device='cuda:0')
# bb_estimate tensor([0.2159, 0.0901, 0.8277, 0.7754], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2620, 0.1600, 0.8640, 0.7320], device='cuda:0')
# train Loss: 0.1083  |  Acc: 0.9890  |  IOU: 0.0244
# bb_estimate tensor([0.2169, 0.0292, 0.9474, 0.7882], device='cuda:0')
# Actual Box tensor([0.0571, 0.0560, 0.7147, 0.5540], device='cuda:0')
# bb_estimate tensor([0.3619, 0.1562, 0.6350, 0.5352], device='cuda:0')
# Actual Box tensor([0.3280, 0.2861, 0.5140, 0.5151], device='cuda:0')
# bb_estimate tensor([0.2377, 0.1596, 0.6192, 0.5851], device='cuda:0')
# Actual Box tensor([0.6360, 0.3013, 0.8900, 0.6532], device='cuda:0')
# bb_estimate tensor([0.4495, 0.0958, 0.6060, 0.4294], device='cuda:0')
# Actual Box tensor([0.5080, 0.1164, 0.7000, 0.4179], device='cuda:0')
# bb_estimate tensor([0.3320, 0.0726, 0.7445, 0.6575], device='cuda:0')
# Actual Box tensor([0.2960, 0.1520, 0.6140, 0.5947], device='cuda:0')
# val Loss: 0.1123  |  Acc: 0.9873  |  IOU: 0.0241
# Epoch 9/10
# ----------
# bb_estimate tensor([0.2877, 0.1086, 0.6972, 0.5322], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.1760, 0.1947, 0.4660, 0.5387], device='cuda:0')
# bb_estimate tensor([0.1933, 0.1213, 0.7783, 0.8125], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2520, 0.0667, 0.7580, 0.7120], device='cuda:0')
# bb_estimate tensor([0.3967, 0.2797, 0.6634, 0.5823], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.7020, 0.3174, 0.9400, 0.6796], device='cuda:0')
# bb_estimate tensor([0.3936, 0.2428, 0.8392, 0.5551], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.5440, 0.0533, 0.9080, 0.5200], device='cuda:0')
# bb_estimate tensor([0.2718, 0.2271, 0.7153, 0.6577], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.0030, 0.0680, 0.7718, 0.6060], device='cuda:0')
# bb_estimate tensor([0.2561, 0.1257, 0.6716, 0.6859], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.1360, 0.0450, 0.7320, 0.9189], device='cuda:0')
# bb_estimate tensor([0.2436, 0.1891, 0.7656, 0.6711], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.0330, 0.1880, 0.6937, 0.6120], device='cuda:0')
# bb_estimate tensor([0.3904, 0.3434, 0.5695, 0.5649], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3840, 0.3013, 0.5400, 0.5280], device='cuda:0')
# bb_estimate tensor([0.4403, 0.1503, 0.6044, 0.4010], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.6500, 0.0632, 0.8160, 0.3022], device='cuda:0')
# bb_estimate tensor([0.3274, 0.1166, 0.7406, 0.5354], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3200, 0.1840, 0.6400, 0.4480], device='cuda:0')
# bb_estimate tensor([0.3044, 0.0902, 0.6357, 0.5048], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2420, 0.0449, 0.5240, 0.5180], device='cuda:0')
# bb_estimate tensor([0.2834, 0.1364, 0.6917, 0.6041], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3632, 0.4520, 0.6266, 0.6960], device='cuda:0')
# bb_estimate tensor([0.2492, 0.0180, 0.6490, 0.5229], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2033, 0.0533, 0.6067, 0.6133], device='cuda:0')
# bb_estimate tensor([0.3498, 0.2071, 0.5867, 0.4952], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.5580, 0.1869, 0.7600, 0.5234], device='cuda:0')
# bb_estimate tensor([0.4999, 0.1727, 0.7635, 0.5947], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4420, 0.0293, 0.8180, 0.5200], device='cuda:0')
# bb_estimate tensor([0.0839, 0.1138, 0.9016, 0.7652], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.0027, 0.1860, 1.0000, 0.9600], device='cuda:0')
# bb_estimate tensor([0.2058, 0.1900, 0.6509, 0.5314], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2886, 0.1540, 0.5971, 0.6200], device='cuda:0')
# bb_estimate tensor([0.2874, 0.1351, 0.6365, 0.5164], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.5160, 0.0360, 0.7960, 0.4595], device='cuda:0')
# bb_estimate tensor([0.3495, 0.2515, 0.6755, 0.6197], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3800, 0.2587, 0.6240, 0.6507], device='cuda:0')
# bb_estimate tensor([0.3751, 0.2034, 0.6273, 0.4649], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3640, 0.1471, 0.5960, 0.5195], device='cuda:0')
# train Loss: 0.1272  |  Acc: 0.9811  |  IOU: 0.0246
# bb_estimate tensor([0.3148, 0.1784, 0.6008, 0.5171], device='cuda:0')
# Actual Box tensor([0.4740, 0.2693, 0.7460, 0.6053], device='cuda:0')
# bb_estimate tensor([0.2117, 0.1280, 0.6664, 0.4765], device='cuda:0')
# Actual Box tensor([0.1860, 0.0729, 0.6240, 0.5198], device='cuda:0')
# bb_estimate tensor([0.3606, 0.2401, 0.5323, 0.4726], device='cuda:0')
# Actual Box tensor([0.5760, 0.2633, 0.7480, 0.5406], device='cuda:0')
# bb_estimate tensor([0.3062, 0.1763, 0.5232, 0.4421], device='cuda:0')
# Actual Box tensor([0.4000, 0.0933, 0.5600, 0.3200], device='cuda:0')
# bb_estimate tensor([0.1668, 0.1024, 0.7271, 0.5780], device='cuda:0')
# Actual Box tensor([0.0773, 0.0920, 0.8720, 0.5380], device='cuda:0')
# val Loss: 0.0999  |  Acc: 0.9873  |  IOU: 0.0242
# Epoch 10/10
# ----------
# bb_estimate tensor([0.3431, 0.1175, 0.7575, 0.6141], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4420, 0.0293, 0.8180, 0.5200], device='cuda:0')
# bb_estimate tensor([0.2631, 0.2582, 0.4370, 0.4723], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3880, 0.4048, 0.5120, 0.5710], device='cuda:0')
# bb_estimate tensor([0.4331, 0.1933, 0.5400, 0.4242], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3050, 0.0400, 0.5400, 0.4067], device='cuda:0')
# bb_estimate tensor([0.3277, 0.1607, 0.5825, 0.3033], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2643, 0.1880, 0.6216, 0.3900], device='cuda:0')
# bb_estimate tensor([0.3405, 0.1738, 0.6433, 0.5613], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3360, 0.0571, 0.6620, 0.4865], device='cuda:0')
# bb_estimate tensor([0.3225, 0.2729, 0.5437, 0.5257], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.1560, 0.3947, 0.3800, 0.6987], device='cuda:0')
# bb_estimate tensor([0.2616, 0.1656, 0.6159, 0.5787], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4480, 0.2063, 0.7220, 0.5737], device='cuda:0')
# bb_estimate tensor([0.2644, 0.0644, 0.7011, 0.4724], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3567, 0.0760, 0.8371, 0.4580], device='cuda:0')
# bb_estimate tensor([0.3282, 0.1097, 0.6725, 0.3435], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4560, 0.1960, 0.8107, 0.4600], device='cuda:0')
# bb_estimate tensor([0.3052, 0.0235, 0.7886, 0.5826], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2000, 0.0178, 0.6889, 0.5111], device='cuda:0')
# bb_estimate tensor([0.2299, 0.2340, 0.6544, 0.5672], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3609, 0.6150, 0.6729, 0.8200], device='cuda:0')
# bb_estimate tensor([0.3218, 0.0371, 0.6972, 0.4880], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.4367, 0.0356, 0.7633, 0.5200], device='cuda:0')
# bb_estimate tensor([0.3872, 0.1617, 0.5720, 0.4278], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.3180, 0.1622, 0.5320, 0.4925], device='cuda:0')
# bb_estimate tensor([0.2054, 0.1179, 0.8832, 0.7129], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.0030, 0.1040, 0.9940, 0.6980], device='cuda:0')
# bb_estimate tensor([0.3079, 0.0771, 0.4943, 0.3293], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.0425, 0.0024, 0.2550, 0.1929], device='cuda:0')
# bb_estimate tensor([0.2033, 0.0922, 0.7162, 0.6166], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2333, 0.0044, 0.7600, 0.6356], device='cuda:0')
# bb_estimate tensor([0.4596, 0.1980, 0.5762, 0.3687], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.5020, 0.3227, 0.6320, 0.5093], device='cuda:0')
# bb_estimate tensor([0.2918, 0.1443, 0.7582, 0.5688], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2143, 0.1520, 0.8801, 0.7060], device='cuda:0')
# bb_estimate tensor([0.0887, 0.0579, 0.7871, 0.7115], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.2020, 0.0901, 0.7520, 0.8318], device='cuda:0')
# bb_estimate tensor([0.3265, 0.1889, 0.6444, 0.4786], device='cuda:0',
#        grad_fn=<SelectBackward0>)
# Actual Box tensor([0.5600, 0.1156, 0.9067, 0.5511], device='cuda:0')
# train Loss: 0.0788  |  Acc: 0.9937  |  IOU: 0.0248
# bb_estimate tensor([0.2705, 0.1704, 0.7039, 0.6653], device='cuda:0')
# Actual Box tensor([0.3600, 0.0571, 0.6680, 0.5435], device='cuda:0')
# bb_estimate tensor([0.3053, 0.0884, 0.6057, 0.4394], device='cuda:0')
# Actual Box tensor([0.2006, 0.0360, 0.5539, 0.3320], device='cuda:0')
# bb_estimate tensor([0.3356, 0.1793, 0.6962, 0.5351], device='cuda:0')
# Actual Box tensor([0.3453, 0.1620, 0.8559, 0.4560], device='cuda:0')
# bb_estimate tensor([0.1950, 0.0813, 0.7139, 0.6950], device='cuda:0')
# Actual Box tensor([0.4060, 0.1573, 0.7500, 0.5947], device='cuda:0')
# bb_estimate tensor([0.1816, 0.1697, 0.7560, 0.7558], device='cuda:0')
# Actual Box tensor([0.3000, 0.1856, 0.6340, 0.6737], device='cuda:0')
# val Loss: 0.1166  |  Acc: 0.9873  |  IOU: 0.0241
# Training complete in 1m 25s
# Best val Acc: 0.987342

# %% [markdown]
# Once you are pleased with your results, see how your model can predict and localize cats and dogs!

# %%
# Get a batch of validation data
sample = next(iter(dataloaders['val']))
with torch.no_grad():
    images = sample['image']
    images = images.to(device)
    label_pred, bbox_pred = best_model(images)
    _, label_pred = torch.max(label_pred, 1)
imshow(sample['image'], label_pred.cpu(), bbox_pred.cpu())
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4305114e-08..1.0].

# %% [markdown]
# ## visualizations
#
# Your visualizations here:
# - IoU / Accuracy / Loss on training and validation datasets as a function of the epoch).
# - Only visualize the results of your best model.
#
# **(10 Points)**

# %%
def plot_metrics(history):
    """
    Visualize IoU, Accuracy, and Loss over epochs.

    Args:
        history: Dictionary containing training and validation metrics.
    """
#############################################################################
#                           START OF YOUR CODE                              #
#############################################################################















#############################################################################
#                             END OF YOUR CODE                              #
#############################################################################

# %%
plot_metrics(history)
